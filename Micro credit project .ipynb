# %%
import pandas as pd 
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Data file.csv')
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
df.shape
# Out:
# (209593, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# # checking null values

# %%
sb.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# ### Detail of unique values of columns if they are categorical

# %%
for i in df.columns:
    print('Unique columns of',i,df[i].unique(),'\n',df[i].value_counts(),'\n')
# Out:
# Unique columns of Unnamed: 0 [     1      2      3 ... 209591 209592 209593]
#  2049      1
# 23969     1
# 126359    1
# 103832    1
# 105881    1
#          ..
# 57929     1
# 64074     1
# 62027     1
# 51788     1
# 2047      1
# Name: Unnamed: 0, Length: 209593, dtype: int64
#
# Unique columns of label [0 1]
#  1    183431
# 0     26162
# Name: label, dtype: int64
#
# Unique columns of msisdn ['21408I70789' '76462I70374' '17943I70372' ... '22758I85348' '59712I82733'
#  '65061I85339']
#  47819I90840    7
# 04581I85330    7
# 29191I82738    6
# 87592I84456    6
# 94119I84456    6
#               ..
# 29064I88680    1
# 69447I90581    1
# 46977I81939    1
# 51528I84452    1
# 49862I90583    1
# Name: msisdn, Length: 186243, dtype: int64
#
# Unique columns of aon [2.72000000e+02 7.12000000e+02 5.35000000e+02 ... 8.03380622e+05
#  5.81435484e+05 8.11881373e+05]
#  95.000000        392
# 92.000000        362
# 96.000000        357
# 99.000000        356
# 157.000000       349
# ...

# %%
df['rental30'].max()
# Out:
# 198926.11

# %%
df['rental90'].max()
# Out:
# 200148.11

# %%
pd.set_option('max_columns',None)

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['aon']<0]
# Out:
#         Unnamed: 0  label       msisdn   aon  daily_decr30  daily_decr90  \
# 30              31      1  70130I90843 -42.0      8.864333      8.864333
# 197            198      1  46858I90841 -36.0     32.075333     32.075333
# 322            323      1  03027I70379 -37.0      9.160000      9.160000
# 504            505      1  75670I84458 -36.0     11.470333     11.470333
# 603            604      1  58495I89235 -35.0     12.474000     12.474000
# ...            ...    ...          ...   ...           ...           ...
# 208716      208717      1  10162I90589 -34.0     19.260000     19.260000
# 209121      209122      1  65511I84450 -18.0    700.580000    700.600000
# 209240      209241      1  34896I70375 -28.0     10.640000     10.640000
# 209421      209422      1  51717I84459 -44.0      7.166667      7.166667
# 209514      209515      0  50508I70786  -2.0   1030.000000   1030.000000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# ...

# %%
cate=[]
conti=[]

# %%
for  i in df.columns:
    if df[i].dtype=='O':
        cate.append(i)
    else:
        df[i].dtype!='O'
        conti.append(i)

# %%
df[conti]=df[conti].apply(abs)

# %% [markdown]
#   continous data =
#
#          ['Unnamed: 0','label','aon','daily_decr30','daily_decr90','rental30','rental90','last_rech_date_ma',
#            'last_rech_date_da','last_rech_amt_ma','cnt_ma_rech30','fr_ma_rech30','sumamnt_ma_rech30',
#            'medianamnt_ma_rech30','medianmarechprebal30','cnt_ma_rech90','fr_ma_rech90','sumamnt_ma_rech90',
#            'medianamnt_ma_rech90','medianmarechprebal90','cnt_da_rech30','fr_da_rech30','cnt_da_rech90','fr_da_rech90'
#            ,'cnt_loans30','amnt_loans30','maxamnt_loans30','medianamnt_loans30','cnt_loans90','amnt_loans90',
#            'maxamnt_loans90','medianamnt_loans90','payback30','payback90']
#
#   categorical data =
#
#                    ['msisdn', 'pcircle', 'pdate']

# %% [markdown]
# # Lets perform some EDA

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.shape
# Out:
# (209593, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
# drop uncessary columns
df.drop(columns=['Unnamed: 0','pcircle'],axis=1,inplace=True)

df.drop('msisdn',axis=1,inplace=True)

# %%
df['pdate'].dtype
df['pdate']=pd.to_datetime(df['pdate'])

# %%
df['month']=pd.to_datetime(df['pdate'],format="%Y-%m-%d").dt.month
df['day']=pd.to_datetime(df['pdate'],format="%Y-%m-%d").dt.day
df['year']=pd.to_datetime(df['pdate'],format="%y-%m-%d").dt.year

# %%
df['year']==2016
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 209588    True
# 209589    True
# 209590    True
# 209591    True
# 209592    True
# Name: year, Length: 209593, dtype: bool

# %%
df.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pdate', 'month', 'day', 'year'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                          count          mean           std     min  \
# label                 209593.0      0.875177      0.330519     0.0
# aon                   209593.0   8112.808718  75696.032666     1.0
# daily_decr30          209593.0   5381.431293   9220.606472     0.0
# daily_decr90          209593.0   6082.544140  10918.796572     0.0
# rental30              209593.0   2715.376558   4294.257439     0.0
# rental90              209593.0   3509.497148   5754.630600     0.0
# last_rech_date_ma     209593.0   3756.125844  53905.872857     0.0
# last_rech_date_da     209593.0   3712.204801  53374.833299     0.0
# last_rech_amt_ma      209593.0   2064.452797   2370.786034     0.0
# cnt_ma_rech30         209593.0      3.978057      4.256090     0.0
# fr_ma_rech30          209593.0   3737.355121  53643.625172     0.0
# sumamnt_ma_rech30     209593.0   7704.501157  10139.621714     0.0
# medianamnt_ma_rech30  209593.0   1812.817952   2070.864620     0.0
# ...

# %%
df.drop(columns=['medianamnt_loans90','medianamnt_loans30','fr_da_rech90','last_rech_date_da','cnt_da_rech30',
                 'fr_da_rech30','cnt_da_rech90'],axis=1,inplace=True)
# most of these columns has lots of 0 values.

# %%
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# ...

# %%
df.describe().T
# Out:
#                          count          mean           std     min  \
# label                 209593.0      0.875177      0.330519     0.0
# aon                   209593.0   8112.808718  75696.032666     1.0
# daily_decr30          209593.0   5381.431293   9220.606472     0.0
# daily_decr90          209593.0   6082.544140  10918.796572     0.0
# rental30              209593.0   2715.376558   4294.257439     0.0
# rental90              209593.0   3509.497148   5754.630600     0.0
# last_rech_date_ma     209593.0   3756.125844  53905.872857     0.0
# last_rech_amt_ma      209593.0   2064.452797   2370.786034     0.0
# cnt_ma_rech30         209593.0      3.978057      4.256090     0.0
# fr_ma_rech30          209593.0   3737.355121  53643.625172     0.0
# sumamnt_ma_rech30     209593.0   7704.501157  10139.621714     0.0
# medianamnt_ma_rech30  209593.0   1812.817952   2070.864620     0.0
# medianmarechprebal30  209593.0   3854.219020  54006.210975     0.0
# ...

# %%
df['maxamnt_loans30'].min(),df['maxamnt_loans30'].max()
# Out:
# (0.0, 99864.5608639345)

# %% [markdown]
# ### as per description there are only two options 1--- rs.5 which pay back rs.6 and 2---rs.10 which pay back at rs.12 so other than that amount we consider that it 0.

# %%
df.loc[(df['maxamnt_loans30']!=6.0)&(df['maxamnt_loans30']!=12.0)&(df['maxamnt_loans30']!=0.0),'maxamnt_loans30']
# Out:
# 118       61907.697372
# 125       22099.413732
# 146       98745.934048
# 369       58925.364061
# 374       78232.464324
#               ...
# 209189    50824.996349
# 209262    17324.994582
# 209331    92864.501728
# 209392    54259.265687
# 209424    96927.243252
# Name: maxamnt_loans30, Length: 1047, dtype: float64

# %%
df.loc[(df['maxamnt_loans30']!=6.0) & (df['maxamnt_loans30']!=12.0) &(df['maxamnt_loans30']!=0.0),'maxamnt_loans30']=0.0

# %%
df['maxamnt_loans30'].value_counts()
# Out:
# 6.0     179193
# 12.0     26109
# 0.0       4291
# Name: maxamnt_loans30, dtype: int64

# %%
df['maxamnt_loans90'].value_counts()
# Out:
# 6     180945
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64

# %%
df.drop(df[df['amnt_loans30']==0].index,inplace=True)

# %%
continous_feature=[i for i in df.columns if df[i].dtype!='O' ]

# %%
len(continous_feature)
# Out:
# 30

# %%
r=df[continous_feature]
r
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# ...

# %%
plt.figure(figsize=(37,38))
num=1

for i  in r.columns:
    
    if num<=30:
        ax=plt.subplot(10,3,num)
        sb.distplot(df[i])
        plt.xlabel(i,fontsize=20)
        
    num+=1
plt.tight_layout()
plt.savefig('distplot_micro credit')

# %%
df.drop(columns=['pdate','year'],axis=1,inplace=True)

# %%
continous_feature=[i for i in df.columns if df[i].dtype!='O']
len(continous_feature)
# Out:
# 28

# %%
plt.figure(figsize=(37,38))
num=1

for i  in df[continous_feature]:
    
    if num<=30:
        ax=plt.subplot(10,3,num)
        sb.boxplot(df[i])
        plt.xlabel(i,fontsize=20)
        
    num+=1
plt.tight_layout()
plt.savefig('outliers_micro crediter')

# %% [markdown]
# lots of outliers are present in here in most of columns

# %%
sb.countplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
continous=['aon','daily_decr30','daily_decr90','rental30','rental90','last_rech_date_ma','last_rech_amt_ma','cnt_ma_rech30','fr_ma_rech30','sumamnt_ma_rech30','medianamnt_ma_rech30','medianmarechprebal30','cnt_ma_rech90','fr_ma_rech90','sumamnt_ma_rech90','medianamnt_ma_rech90','medianmarechprebal90','cnt_loans30','amnt_loans30','maxamnt_loans30','cnt_loans90','amnt_loans90','maxamnt_loans90','payback30','payback90','month','day']

# %%
len(continous)
# Out:
# 27

# %%
plt.figure(figsize=(40,100))
num=1

for i  in df[continous]:
    
    if num<=30:
        ax=plt.subplot(10,3,num)
        sb.barplot(x=df['label'],y=df[i])
        plt.xlabel('label',fontsize=25)
        plt.ylabel(i,fontsize=25)
    num+=1
plt.tight_layout()
plt.savefig('continous vs target')

# %%
#Checking the correlation with target variable
plt.figure(figsize=(16,8))
df.drop('label', axis=1).corrwith(df['label']).plot(kind='bar',grid=False)
plt.xticks(rotation='vertical')
plt.title("Correlation with target Variable that is label column",fontsize=25)
plt.savefig('corr_mcredit')

# %%
#Customer label according to per day:
plt.figure(figsize=(16,8))
sb.countplot(x="day", hue='label', data=df, palette='rocket')
plt.title("Customers label according to Date", fontsize=25)
plt.xlabel('Date')
plt.ylabel('Counting of Customers')
plt.show()

# %%
#Customer label according to month (date):
plt.figure(figsize=(16,8))
sb.countplot(x="month", hue='label', data=df, palette='rocket')
plt.title("Customers label according to month", fontsize=25)
plt.xlabel('month')
plt.ylabel('Counting of Customers')
plt.show()

# %%
#plotting the Histogram
df.hist(figsize=(20,20),color='r')
plt.show()

# %% [markdown]
# # correlation

# %%
len(df.columns)
# Out:
# 28

# %%
corr_matrix = df.corr()
corr_matrix["label"].sort_values(ascending=False)
# Out:
# label                   1.000000
# cnt_ma_rech30           0.240686
# cnt_ma_rech90           0.238356
# sumamnt_ma_rech90       0.206958
# amnt_loans30            0.205401
# amnt_loans90            0.205371
# sumamnt_ma_rech30       0.205067
# cnt_loans30             0.204850
# daily_decr30            0.168118
# daily_decr90            0.165731
# month                   0.149599
# medianamnt_ma_rech30    0.142099
# last_rech_amt_ma        0.131584
# medianamnt_ma_rech90    0.120416
# maxamnt_loans90         0.102042
# maxamnt_loans30         0.097551
# fr_ma_rech90            0.084324
# rental90                0.074349
# rental30                0.057322
# payback30               0.050335
# payback90               0.050024
# medianmarechprebal90    0.037655
# day                     0.009148
# cnt_loans90             0.004911
# last_rech_date_ma       0.003712
# fr_ma_rech30            0.001255
# aon                    -0.003973
# medianmarechprebal30   -0.004903
# ...

# %%
plt.figure(figsize=(24,18))
sb.heatmap(corr_matrix, annot=True, cmap='icefire')
plt.title("Correlation Matrix")
plt.show()
plt.savefig('mat')

# %%
corr_matrix = df.corr()
corr_matrix["label"].sort_values(ascending=False)
# Out:
# label                   1.000000
# cnt_ma_rech30           0.240686
# cnt_ma_rech90           0.238356
# sumamnt_ma_rech90       0.206958
# amnt_loans30            0.205401
# amnt_loans90            0.205371
# sumamnt_ma_rech30       0.205067
# cnt_loans30             0.204850
# daily_decr30            0.168118
# daily_decr90            0.165731
# month                   0.149599
# medianamnt_ma_rech30    0.142099
# last_rech_amt_ma        0.131584
# medianamnt_ma_rech90    0.120416
# maxamnt_loans90         0.102042
# maxamnt_loans30         0.097551
# fr_ma_rech90            0.084324
# rental90                0.074349
# rental30                0.057322
# payback30               0.050335
# payback90               0.050024
# medianmarechprebal90    0.037655
# day                     0.009148
# cnt_loans90             0.004911
# last_rech_date_ma       0.003712
# fr_ma_rech30            0.001255
# aon                    -0.003973
# medianmarechprebal30   -0.004903
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206334 entries, 0 to 209592
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 206334 non-null  int64
#  1   aon                   206334 non-null  float64
#  2   daily_decr30          206334 non-null  float64
#  3   daily_decr90          206334 non-null  float64
#  4   rental30              206334 non-null  float64
#  5   rental90              206334 non-null  float64
#  6   last_rech_date_ma     206334 non-null  float64
#  7   last_rech_amt_ma      206334 non-null  int64
#  8   cnt_ma_rech30         206334 non-null  int64
#  9   fr_ma_rech30          206334 non-null  float64
#  10  sumamnt_ma_rech30     206334 non-null  float64
#  11  medianamnt_ma_rech30  206334 non-null  float64
#  12  medianmarechprebal30  206334 non-null  float64
#  13  cnt_ma_rech90         206334 non-null  int64
# ...

# %%
cat_df,conti_df=[],[]

for i in df.columns:
    if df[i].dtype=='O':
        cat_df.append(i)
    elif (df[i].dtypes=='int64') | (df[i].dtypes=='float64') | (df[i].dtypes=='int32'):
        conti_df.append(i)
    else:
        continue
        
        
print(cat_df)
print(conti_df,'\n')
print(len(conti_df))
# Out:
# []
# ['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_loans30', 'amnt_loans30', 'maxamnt_loans30', 'cnt_loans90', 'amnt_loans90', 'maxamnt_loans90', 'payback30', 'payback90', 'month', 'day']
#
# 28

# %% [markdown]
# # Removing outliers for from feature columns

# %%
X=df.drop(columns=['month','day','label'],axis=1)
y=df['label']

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(X))

# %%
k=np.where(z>3)[0]
len(np.where(z>3)[0])
# Out:
# 80451

# %%
df1=df

# %%
df.reset_index(inplace=True)

# %%
df.drop('index',axis=1,inplace=True)

# %%
df1=df

# %%
df1.drop(index=k,axis=1,inplace=True)

# %%
df1
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 206329      1   404.0    151.872333    151.872333   1089.19   1089.19
# 206330      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 206331      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 206332      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 206333      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# ...

# %%
plt.figure(figsize=(17,15))
sb.heatmap(df.corr(),annot=True,center=0,linewidth=0.5,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # checking VIF

# %%
X=df1.drop('label',axis=1)
Y=df1['label']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = np.round([variance_inflation_factor(X.values, i) 
                   for i in range(len(X.columns))])
vif_data.sort_values(by='VIF',ascending=False)
# Out:
#                  feature     VIF
# 21          amnt_loans90  3891.0
# 20           cnt_loans90  3582.0
# 18          amnt_loans30  2476.0
# 17           cnt_loans30  2241.0
# 19       maxamnt_loans30  1452.0
# 22       maxamnt_loans90  1400.0
# 25                 month    51.0
# 2           daily_decr90    49.0
# 1           daily_decr30    45.0
# 12         cnt_ma_rech90    35.0
# 7          cnt_ma_rech30    33.0
# 14     sumamnt_ma_rech90    27.0
# 9      sumamnt_ma_rech30    25.0
# 4               rental90    21.0
# 3               rental30    19.0
# 15  medianamnt_ma_rech90    11.0
# 10  medianamnt_ma_rech30    10.0
# 6       last_rech_amt_ma     6.0
# 23             payback30     4.0
# 24             payback90     4.0
# 26                   day     4.0
# 0                    aon     3.0
# 16  medianmarechprebal90     3.0
# 11  medianmarechprebal30     3.0
# 8           fr_ma_rech30     2.0
# 5      last_rech_date_ma     2.0
# 13          fr_ma_rech90     2.0

# %% [markdown]
# # Feature selection

# %%
from sklearn.tree import DecisionTreeClassifier
select= DecisionTreeClassifier()
select.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
add=np.round(select.feature_importances_,3)
add
# Out:
# array([0.078, 0.081, 0.242, 0.062, 0.049, 0.032, 0.01 , 0.005, 0.012,
#        0.027, 0.018, 0.029, 0.064, 0.017, 0.027, 0.011, 0.037, 0.004,
#        0.004, 0.001, 0.005, 0.004, 0.002, 0.008, 0.013, 0.063, 0.096])

# %%
0.077+ 0.083+ 0.242+ 0.062+ 0.047+ 0.032+ 0.009+ 0.004+ 0.012+0.027+ 0.019+ 0.029+ 0.065+ 0.018+ 0.027+ 0.011+ 0.036+ 0.005+0.003+ 0.001+ 0.005+ 0.004+ 0.001+ 0.008+ 0.013+ 0.063+ 0.095
# Out:
# 0.9980000000000002

# %% [markdown]
# although there are some columns which shows multicollinerity problem so, we need to drop some of columns

# %%
X.drop(columns=['amnt_loans90','cnt_loans90','amnt_loans30','cnt_loans30','maxamnt_loans30','maxamnt_loans90'],axis=1)
# Out:
#            aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        272.0   3055.050000   3065.150000    220.13    260.13
# 1        712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        535.0   1398.000000   1398.000000    900.13    900.13
# 3        241.0     21.228000     21.228000    159.42    159.42
# 4        947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...           ...           ...       ...       ...
# 206329   404.0    151.872333    151.872333   1089.19   1089.19
# 206330  1075.0     36.936000     36.936000   1728.36   1728.36
# 206331  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 206332  1732.0  12488.228333  12574.370000    411.83    984.58
# 206333  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 0                     2.0              1539              2          21.0
# ...

# %%
X
# Out:
#            aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        272.0   3055.050000   3065.150000    220.13    260.13
# 1        712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        535.0   1398.000000   1398.000000    900.13    900.13
# 3        241.0     21.228000     21.228000    159.42    159.42
# 4        947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...           ...           ...       ...       ...
# 206329   404.0    151.872333    151.872333   1089.19   1089.19
# 206330  1075.0     36.936000     36.936000   1728.36   1728.36
# 206331  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 206332  1732.0  12488.228333  12574.370000    411.83    984.58
# 206333  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 0                     2.0              1539              2          21.0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
select= DecisionTreeClassifier()
select.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
add=np.round(select.feature_importances_,3)
len(add)
add
# Out:
# array([0.077, 0.079, 0.245, 0.06 , 0.049, 0.033, 0.009, 0.005, 0.012,
#        0.029, 0.016, 0.029, 0.064, 0.018, 0.027, 0.012, 0.037, 0.004,
#        0.004, 0.001, 0.005, 0.005, 0.002, 0.008, 0.013, 0.063, 0.095])

# %%
0.077+ 0.09 + 0.234+ 0.063+ 0.047+ 0.033+ 0.009+ 0.005+ 0.012+ 0.028+ 0.017+ 0.031+ 0.065+ 0.017+ 0.028+ 0.012+ 0.036+ 0.004+ 0.004+ 0.001+ 0.005+ 0.004+ 0.001+ 0.008+ 0.012+ 0.063+ 0.095
# Out:
# 1.0010000000000001

# %% [markdown]
# no change here if we want we can drop some more columns which has least correlation which are contributed very very less in output

# %%
for index,feature_imp in enumerate(select.feature_importances_):
    print(index , feature_imp)
# Out:
# 0 0.07720056284671675
# 1 0.0791715286211289
# 2 0.24524703296514241
# 3 0.0603766717839412
# 4 0.049229423791732604
# 5 0.032601427697026446
# 6 0.008643254000444807
# 7 0.004600650764398483
# 8 0.012358577246211425
# 9 0.028771009994139313
# 10 0.016067235388797826
# 11 0.02904049680338082
# 12 0.06418641691019086
# 13 0.01834034684274648
# 14 0.02679086139881698
# 15 0.012118051845335888
# 16 0.03686597151010528
# 17 0.0038055845467110804
# 18 0.0040201437021840265
# 19 0.0007557022061158072
# 20 0.004950052699324441
# 21 0.004973195201634956
# 22 0.0016011246335867505
# 23 0.007895314551641792
# 24 0.01275456447974003
# 25 0.06273637299648947
# 26 0.09489842457231513

# %%
imp_feature=pd.DataFrame()
imp_feature['Feature']= X.columns
imp_feature['Values']=select.feature_importances_
imp_feature
# Out:
#                  Feature    Values
# 0                    aon  0.077201
# 1           daily_decr30  0.079172
# 2           daily_decr90  0.245247
# 3               rental30  0.060377
# 4               rental90  0.049229
# 5      last_rech_date_ma  0.032601
# 6       last_rech_amt_ma  0.008643
# 7          cnt_ma_rech30  0.004601
# 8           fr_ma_rech30  0.012359
# 9      sumamnt_ma_rech30  0.028771
# 10  medianamnt_ma_rech30  0.016067
# 11  medianmarechprebal30  0.029040
# 12         cnt_ma_rech90  0.064186
# 13          fr_ma_rech90  0.018340
# 14     sumamnt_ma_rech90  0.026791
# 15  medianamnt_ma_rech90  0.012118
# 16  medianmarechprebal90  0.036866
# 17           cnt_loans30  0.003806
# 18          amnt_loans30  0.004020
# 19       maxamnt_loans30  0.000756
# 20           cnt_loans90  0.004950
# 21          amnt_loans90  0.004973
# 22       maxamnt_loans90  0.001601
# 23             payback30  0.007895
# 24             payback90  0.012755
# 25                 month  0.062736
# ...

# %% [markdown]
# # Scaling Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled=StandardScaler()
x_scaled=scaled.fit_transform(X)

# %% [markdown]
# # Balancing data

# %%
Y.value_counts()
# Out:
# 1    142967
# 0     23117
# Name: label, dtype: int64

# %%
sb.countplot(Y)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
y.value_counts(normalize=True)*100
# Out:
# 1    87.320558
# 0    12.679442
# Name: label, dtype: float64

# %%
Y.shape
# Out:
# (166084,)

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()

# %%
n_x,n_y=sm.fit_resample(x_scaled,Y)

# %%
n_y.value_counts()
# Out:
# 0    142967
# 1    142967
# Name: label, dtype: int64

# %% [markdown]
# # Training and building the model and also splitting train test data

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report,f1_score

# %%
LR= LogisticRegression()
import warnings
warnings.filterwarnings('ignore')

# %%
max_accu=0
max_RS=0

for i in range(0,100):
    x_train,x_test,y_train,y_test= train_test_split(n_x,n_y,random_state=i,test_size=.20)
    lr= LogisticRegression()
    lr.fit(x_train,y_train)
    pred= lr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>max_accu:
        max_accu=acc
        max_RS=i
print("Best accuracy is ",max_accu,"on Random State =",max_RS)
# Out:
# Best accuracy is  0.7721859863255635 on Random State = 75

# %%
x_train,x_test,y_train,y_test= train_test_split(n_x,n_y,random_state=75,test_size=0.35)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.neural_network import MLPClassifier

# %%
lr_model=LogisticRegression()
dt_model=DecisionTreeClassifier()
knn_model=KNeighborsClassifier()
rd_model=RandomForestClassifier()
xgb_model=XGBClassifier()
bag_model=BaggingClassifier()
ada_model=AdaBoostClassifier()
gd_model=GradientBoostingClassifier()
et_model=ExtraTreeClassifier()
nural_model=MLPClassifier()

# %%
models=[lr_model,dt_model,knn_model,rd_model,xgb_model,bag_model,ada_model,gd_model,et_model,nural_model]

# %%
for m in models:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predict=m.predict(x_test)
    print('Accuracy Score of ',m, 'is', accuracy_score(y_test,predict))
    print("F1 Score", f1_score(y_test,predict))
    print('Confusion Matrix of ',m,' is \n', confusion_matrix(y_test,predict))
    print('Classification_report',classification_report(y_test,predict))
    print('*******************************************')
# Out:
# Accuracy Score of  LogisticRegression() is 0.771026309741499
# F1 Score 0.760746316965451
# Confusion Matrix of  LogisticRegression()  is
#  [[40731  9292]
#  [13623 36431]]
# Classification_report               precision    recall  f1-score   support
#
#            0       0.75      0.81      0.78     50023
#            1       0.80      0.73      0.76     50054
#
#     accuracy                           0.77    100077
#    macro avg       0.77      0.77      0.77    100077
# weighted avg       0.77      0.77      0.77    100077
#
# *******************************************
# Accuracy Score of  DecisionTreeClassifier() is 0.9029047633322341
# F1 Score 0.9023819330728042
# Confusion Matrix of  DecisionTreeClassifier()  is
#  [[45448  4575]
#  [ 5142 44912]]
# Classification_report               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90     50023
#            1       0.91      0.90      0.90     50054
#
# ...

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in models:
    print('Accuracy_Score of ',i, 'is', accuracy_score(y_test,i.predict(x_test)))
    print("cross Validation accuracy score of ",i ," is ",cross_val_score(i,n_x,n_y,cv=5, scoring='accuracy').mean())
    print('@'*50)
# Out:
# Accuracy_Score of  LogisticRegression() is 0.771026309741499
# cross Validation accuracy score of  LogisticRegression()  is  0.7682752000075815
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Accuracy_Score of  DecisionTreeClassifier() is 0.9029047633322341
# cross Validation accuracy score of  DecisionTreeClassifier()  is  0.9022397481109554
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Accuracy_Score of  KNeighborsClassifier() is 0.8674120926886297
# cross Validation accuracy score of  KNeighborsClassifier()  is  0.8761182621982172
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Accuracy_Score of  RandomForestClassifier() is 0.9433136484906622
# cross Validation accuracy score of  RandomForestClassifier()  is  0.9410319184394803
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Accuracy_Score of  XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
# ...

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
n_estimators=[int(x) for x in np.linspace(start=0,stop=100,num=10)]
max_features=['auto','sqrt','log2']
criterion=['gini','entropy']
max_depth=[2,4]
min_samples_split=[1,2]
bootstrap=[True,False]

# %%
para_grid={'n_estimators':n_estimators,
          'max_features':max_features,
          'criterion':criterion,
          'max_depth':max_depth,
          'min_samples_split':min_samples_split,
          'bootstrap':bootstrap}

# %%
grid=GridSearchCV(RandomForestClassifier(),para_grid,n_jobs=-1)
grid.fit(x_train,y_train)
grid.best_params_
# Out:
# {'bootstrap': False,
#  'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'min_samples_split': 2,
#  'n_estimators': 88}

# %%
rf=RandomForestClassifier(bootstrap=False,criterion='gini',max_depth=8,max_features='auto',min_samples_split=2,n_estimators=88)
rf.fit(x_train,y_train)
pred_rf=rf.predict(x_test)
print(accuracy_score(y_test,pred_rf))
print(confusion_matrix(y_test,pred_rf))
print(classification_report(y_test,pred_rf))
# Out:
# 0.8540124104439581
# [[43498  6525]
#  [ 8085 41969]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86     50023
#            1       0.87      0.84      0.85     50054
#
#     accuracy                           0.85    100077
#    macro avg       0.85      0.85      0.85    100077
# weighted avg       0.85      0.85      0.85    100077

# %% [markdown]
# # Plot roc auc curve

# %%
from sklearn.metrics import roc_auc_score,roc_curve,plot_roc_curve

# %%
dist=plot_roc_curve(rd_model,x_test,y_test)

# %%
pred=rd_model.predict(x_test)

# %%
conf=confusion_matrix(y_test,pred)

# %%
#confusion marix
sb.heatmap(conf,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## AUC is showing 0.98

# %% [markdown]
# ## saving the model

# %%
import pickle
file_name='Micro credit project'
with open(file_name,'wb') as file:
    pickle.dump(rd_model,file)
